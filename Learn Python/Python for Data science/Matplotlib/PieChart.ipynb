# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
langs = ["C++", "C#", "Java", "Python", "Javascript", "Go"]
votes = [20, 49, 100, 80, 70, 92]
explodes = [0.1, 0,0,0,0,0]

# %%
plt.pie(votes)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc43d6db10>,
#   <matplotlib.patches.Wedge at 0x1dc43d6da20>,
#   <matplotlib.patches.Wedge at 0x1dc43d6ca90>,
#   <matplotlib.patches.Wedge at 0x1dc43d6e740>,
#   <matplotlib.patches.Wedge at 0x1dc43d6eb60>,
#   <matplotlib.patches.Wedge at 0x1dc43d6efe0>],
#  [Text(1.0871709995126289, 0.16750885892606324, ''),
#   Text(0.8551250589399573, 0.6919256705549627, ''),
#   Text(-0.2704630322538716, 1.066231564053532, ''),
#   Text(-1.098425755708872, -0.05882906760602323, ''),
#   Text(-0.39851848057419825, -1.0252721690560183, ''),
#   Text(0.8390349231590147, -0.7113511072034305, '')])

# %%
plt.pie(votes, labels=langs)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc44f39420>,
#   <matplotlib.patches.Wedge at 0x1dc44f39330>,
#   <matplotlib.patches.Wedge at 0x1dc44f39ba0>,
#   <matplotlib.patches.Wedge at 0x1dc44f3a020>,
#   <matplotlib.patches.Wedge at 0x1dc44f3a4a0>,
#   <matplotlib.patches.Wedge at 0x1dc44f3a920>],
#  [Text(1.0871709995126289, 0.16750885892606324, 'C++'),
#   Text(0.8551250589399573, 0.6919256705549627, 'C#'),
#   Text(-0.2704630322538716, 1.066231564053532, 'Java'),
#   Text(-1.098425755708872, -0.05882906760602323, 'Python'),
#   Text(-0.39851848057419825, -1.0252721690560183, 'Javascript'),
#   Text(0.8390349231590147, -0.7113511072034305, 'Go')])

# %%
plt.pie(votes, labels=langs, explode=explodes)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc44f98850>,
#   <matplotlib.patches.Wedge at 0x1dc44f98760>,
#   <matplotlib.patches.Wedge at 0x1dc44f99120>,
#   <matplotlib.patches.Wedge at 0x1dc44f99540>,
#   <matplotlib.patches.Wedge at 0x1dc44f999c0>,
#   <matplotlib.patches.Wedge at 0x1dc44f99e40>],
#  [Text(1.1860047267410496, 0.1827369370102508, 'C++'),
#   Text(0.8551250589399573, 0.6919256705549627, 'C#'),
#   Text(-0.2704630322538716, 1.066231564053532, 'Java'),
#   Text(-1.098425755708872, -0.05882906760602323, 'Python'),
#   Text(-0.39851848057419825, -1.0252721690560183, 'Javascript'),
#   Text(0.8390349231590147, -0.7113511072034305, 'Go')])

# %%
plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc45075390>,
#   <matplotlib.patches.Wedge at 0x1dc450752a0>,
#   <matplotlib.patches.Wedge at 0x1dc45075f60>,
#   <matplotlib.patches.Wedge at 0x1dc450765f0>,
#   <matplotlib.patches.Wedge at 0x1dc45076ce0>,
#   <matplotlib.patches.Wedge at 0x1dc45077310>],
#  [Text(1.1860047267410496, 0.1827369370102508, 'C++'),
#   Text(0.8551250589399573, 0.6919256705549627, 'C#'),
#   Text(-0.2704630322538716, 1.066231564053532, 'Java'),
#   Text(-1.098425755708872, -0.05882906760602323, 'Python'),
#   Text(-0.39851848057419825, -1.0252721690560183, 'Javascript'),
#   Text(0.8390349231590147, -0.7113511072034305, 'Go')],
#  [Text(0.6918360905989456, 0.10659654658931296, '4.87%'),
#   Text(0.46643185033088574, 0.37741400212088866, '11.92%'),
#   Text(-0.14752529032029357, 0.5815808531201083, '24.33%'),
#   Text(-0.5991413212957483, -0.03208858233055812, '19.46%'),
#   Text(-0.2173737166768354, -0.5592393649396462, '17.03%'),
#   Text(0.4576554126321898, -0.3880096948382348, '22.38%')])

# %%
plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%", pctdistance=0.8)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc45054130>,
#   <matplotlib.patches.Wedge at 0x1dc44f3b910>,
#   <matplotlib.patches.Wedge at 0x1dc44f9b250>,
#   <matplotlib.patches.Wedge at 0x1dc45108d60>,
#   <matplotlib.patches.Wedge at 0x1dc4510a1d0>,
#   <matplotlib.patches.Wedge at 0x1dc43c63220>],
#  [Text(1.1860047267410496, 0.1827369370102508, 'C++'),
#   Text(0.8551250589399573, 0.6919256705549627, 'C#'),
#   Text(-0.2704630322538716, 1.066231564053532, 'Java'),
#   Text(-1.098425755708872, -0.05882906760602323, 'Python'),
#   Text(-0.39851848057419825, -1.0252721690560183, 'Javascript'),
#   Text(0.8390349231590147, -0.7113511072034305, 'Go')],
#  [Text(0.8895035450557872, 0.1370527027576881, '4.87%'),
#   Text(0.6219091337745144, 0.5032186694945183, '11.92%'),
#   Text(-0.19670038709372478, 0.7754411374934779, '24.33%'),
#   Text(-0.7988550950609977, -0.04278477644074417, '19.46%'),
#   Text(-0.2898316222357806, -0.7456524865861951, '17.03%'),
#   Text(0.6102072168429198, -0.517346259784313, '22.38%')])

# %%
plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%", pctdistance=0.8, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc45198340>,
#   <matplotlib.patches.Wedge at 0x1dc45198250>,
#   <matplotlib.patches.Wedge at 0x1dc45199030>,
#   <matplotlib.patches.Wedge at 0x1dc451996c0>,
#   <matplotlib.patches.Wedge at 0x1dc45199cf0>,
#   <matplotlib.patches.Wedge at 0x1dc4519a380>],
#  [Text(-0.18273693701025084, 1.1860047267410496, 'C++'),
#   Text(-0.6919256705549625, 0.8551250589399576, 'C#'),
#   Text(-1.066231564053532, -0.2704630322538715, 'Java'),
#   Text(0.05882906760602316, -1.098425755708872, 'Python'),
#   Text(1.0252721690560183, -0.3985184805741983, 'Javascript'),
#   Text(0.7113511072034306, 0.8390349231590146, 'Go')],
#  [Text(-0.13705270275768813, 0.8895035450557872, '4.87%'),
#   Text(-0.5032186694945181, 0.6219091337745146, '11.92%'),
#   Text(-0.7754411374934779, -0.19670038709372473, '24.33%'),
#   Text(0.04278477644074412, -0.7988550950609977, '19.46%'),
#   Text(0.7456524865861951, -0.2898316222357806, '17.03%'),
#   Text(0.5173462597843131, 0.6102072168429197, '22.38%')])
