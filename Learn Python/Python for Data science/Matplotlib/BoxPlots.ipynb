# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
heights = np.random.normal(172, 8, 300)

# %%
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2657d3d0760>,
#   <matplotlib.lines.Line2D at 0x2657d3d0a00>],
#  'caps': [<matplotlib.lines.Line2D at 0x2657d3d0ca0>,
#   <matplotlib.lines.Line2D at 0x2657d3d0f40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2657d3d04c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2657d3d11e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2657d3d1480>],
#  'means': []}

# %%
first = np.linspace(0, 10, 25)
second = np.linspace(10, 200, 25)
third = np.linspace(200, 210, 25)
fourth = np.linspace(210, 230, 25)
data = np.concatenate((first, second, third, fourth))

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2657d4d6d10>,
#   <matplotlib.lines.Line2D at 0x2657d4d6fb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2657d4d7250>,
#   <matplotlib.lines.Line2D at 0x2657d4d74f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2657d4d6a70>],
#  'medians': [<matplotlib.lines.Line2D at 0x2657d4d7790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2657d4d7a00>],
#  'means': []}
