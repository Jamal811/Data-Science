# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = ["C++", "C#", "Java", "Python", "Javascript", "Go"]
Y = [20, 49, 100, 80, 70, 92]

# %%
plt.bar(X, Y, color='red', align='edge', width=0.5, edgecolor='blue', lw=3)
# Out:
# <BarContainer object of 6 artists>
