# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ages = np.random.normal(20, 1.5, 1000)

# %%
plt.hist(ages)
# Out:
# (array([  3.,  25.,  63., 128., 227., 245., 178.,  83.,  38.,  10.]),
#  array([15.10127112, 16.03065076, 16.9600304 , 17.88941005, 18.81878969,
#         19.74816933, 20.67754898, 21.60692862, 22.53630826, 23.46568791,
#         24.39506755]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages, bins=20)
# Out:
# (array([  2.,   1.,  12.,  13.,  23.,  40.,  62.,  66., 113., 114., 118.,
#         127., 104.,  74.,  55.,  28.,  17.,  21.,   5.,   5.]),
#  array([15.10127112, 15.56596094, 16.03065076, 16.49534058, 16.9600304 ,
#         17.42472022, 17.88941005, 18.35409987, 18.81878969, 19.28347951,
#         19.74816933, 20.21285915, 20.67754898, 21.1422388 , 21.60692862,
#         22.07161844, 22.53630826, 23.00099808, 23.46568791, 23.93037773,
#         24.39506755]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(ages, bins=20, cumulative=True)
# Out:
# (array([   2.,    3.,   15.,   28.,   51.,   91.,  153.,  219.,  332.,
#          446.,  564.,  691.,  795.,  869.,  924.,  952.,  969.,  990.,
#          995., 1000.]),
#  array([15.10127112, 15.56596094, 16.03065076, 16.49534058, 16.9600304 ,
#         17.42472022, 17.88941005, 18.35409987, 18.81878969, 19.28347951,
#         19.74816933, 20.21285915, 20.67754898, 21.1422388 , 21.60692862,
#         22.07161844, 22.53630826, 23.00099808, 23.46568791, 23.93037773,
#         24.39506755]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(ages, bins=[ages.min(), 18, 21, ages.max()])
# Out:
# (array([104., 663., 233.]),
#  array([15.10127112, 18.        , 21.        , 24.39506755]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(ages, bins=20, color='b')
# Out:
# (array([  2.,   1.,  12.,  13.,  23.,  40.,  62.,  66., 113., 114., 118.,
#         127., 104.,  74.,  55.,  28.,  17.,  21.,   5.,   5.]),
#  array([15.10127112, 15.56596094, 16.03065076, 16.49534058, 16.9600304 ,
#         17.42472022, 17.88941005, 18.35409987, 18.81878969, 19.28347951,
#         19.74816933, 20.21285915, 20.67754898, 21.1422388 , 21.60692862,
#         22.07161844, 22.53630826, 23.00099808, 23.46568791, 23.93037773,
#         24.39506755]),
#  <BarContainer object of 20 artists>)
