# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
years = [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
income = [50, 52, 65, 66, 85, 87, 91, 94]
income_ticks = list(range(48, 95, 2))

# %%
plt.plot(years, income)

# %%
plt.plot(years, income)
plt.title("Income of Shah (in USD)", fontsize=20, fontname='FreeSerif')
plt.xlabel("Years")
plt.ylabel("Years Income in USD")
plt.yticks(income_ticks, [f"${x}k" for x in income_ticks])
plt.show()
# Out:
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.

# %%
stock1_prices = [100.25, 102.50, 98.75, 105.00, 99.80, 97.50, 101.25]
stock2_prices = [103.75, 99.50, 98.25, 104.25, 101.80, 110.50, 80.75]
stock3_prices = [80.00, 85.25, 90.50, 99.75, 84.80, 75.50, 87.25]

# %%
plt.plot(stock1_prices, label='company1')
plt.plot(stock2_prices, label='company2')
plt.plot(stock3_prices, label='company3')
plt.legend(loc="lower center")
plt.show()

# %%
votes = [10, 2, 5,16, 22]
people = ["A", "B", "C", "D", "E"]

# style.use('ggplot')

plt.pie(votes, labels=None)
plt.legend(labels =people)
plt.show()

# %%
votes = [10, 2, 5,16, 22]
people = ["A", "B", "C", "D", "E"]

# style.use('dark_background')

plt.pie(votes, labels=None)
plt.legend(labels =people)
plt.show()

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

# style.use('ggplot')


plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

plt.show()

# %% [markdown]
# ## different subplots in one window

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(0.1, 10, 100)  # Adjust the range to avoid values <= 0

# Create subplots
fig, axs = plt.subplots(2, 2)

# Plot sine wave
axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title("Sine Wave")

# Plot cosine wave
axs[0, 1].plot(x, np.cos(x))
axs[0, 1].set_title("Cosine Wave")

# Plot random function
axs[1, 0].plot(x, np.random.random(100))
axs[1, 0].set_title("Random Function")

# Plot log function
axs[1, 1].plot(x, np.log(x))
axs[1, 1].set_title("Log Function")
axs[1, 1].set_xlabel('Test')

# Add suptitle
fig.suptitle("Four Plots")

plt.tight_layout()

# Display the plot
plt.show()

# %%
plt.savefig("fourplots.png", dpi=300, transparent=False, bbox_inches="tight")

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)


# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# %% [markdown]
# ## 3d ploting and animations

# %%
ax = plt.axes(projection="3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x,y,z)
ax.set_title("3D Plot")
ax.set_xlabel("Test")

plt.show()

# %%
ax = plt.axes(projection="3d")

x = np.arange(0, 50, 0.1)
y = np.arange(0, 50, 0.1)
z = np.cos(x + y)

ax.scatter(x,y,z)
ax.set_title("3D Plot")
ax.set_xlabel("Test")

plt.show()

# %%
ax = plt.axes(projection="3d")

x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x,y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X,Y,Z, cmap="Spectral")
ax.set_title("3D Plot")
ax.set_xlabel("Test")
# ax.view_init(azim=0, elev =90)

plt.show()

# %%
# import random

# heads_tails = [0, 0]

# for _ in range(100000):
#     heads_tails[random.randint(0,1)] +=1
#     plt.bar(["Heads", "Tails"], heads_tails, color=["red", "blue"])
#     plt.pause(0.001)
# plt.show()
